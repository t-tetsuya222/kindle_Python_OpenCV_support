# %%
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use("ggplot")

img = cv2.imread("src/Lena.jpg",0)
#ヒストグラムの計算
hist = cv2.calcHist([img],[0],None,[256],[0,256])
plt.plot(hist)
# Out:
# C:\Users\tetsuya\Anaconda3\envs\opencv\lib\site-packages\matplotlib\font_manager.py:1297: UserWarning: findfont: Font family ['IPAexGothic'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
# ヒストグラム均一化
img_eq = cv2.equalizeHist(img)
hist_eq = cv2.calcHist([img_eq],[0],None,[256],[0,256])
plt.plot(hist_eq)
# Out:
# C:\Users\tetsuya\Anaconda3\envs\opencv\lib\site-packages\matplotlib\font_manager.py:1297: UserWarning: findfont: Font family ['IPAexGothic'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
# オリジナルの画像
cv2.imshow("img", img)
# ヒストグラム均一化後の画像
cv2.imshow("equalize_img", img_eq)
cv2.waitKey(0)
cv2.destroyAllWindows()
